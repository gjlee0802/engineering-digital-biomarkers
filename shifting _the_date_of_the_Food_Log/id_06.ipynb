# %%
import pandas as pd
import numpy as np
from scipy.signal import find_peaks, peak_prominences
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection

# %% [markdown]
# Dexcom
# 2020-02-28 12:18:14
# 2020-03-09 09:27:51
#
# Empatica E4
# 2020-02-28 10:20:06
# 2020-03-09 09:45:39
#
# Food Log
# 2020-02-28 08:10:00
# 2020-03-09 07:30:00

# %%
fl_df = pd.read_csv('../big-ideas-lab-glycemic-variability-and-wearable-device-data-1.1.2/006/Food_Log_006.csv')

fl_df['date']=pd.to_datetime(fl_df['date'])
fl_df['time_begin']=pd.to_datetime(fl_df['time_begin'])

# %%
dexcom_df = pd.read_csv('../big-ideas-lab-glycemic-variability-and-wearable-device-data-1.1.2/006/Dexcom_006.csv')
dexcom_df.drop(dexcom_df.loc[:11].index, inplace=True)
dexcom_df.rename(columns = {'Timestamp (YYYY-MM-DDThh:mm:ss)': 'datetime'}, inplace = True)
dexcom_df['datetime']=pd.to_datetime(dexcom_df['datetime'])

# %%
dexcom_df.iloc[0]['datetime']
# Out:
# Timestamp('2020-02-28 12:18:14')

# %% [markdown]
# ## 2020-02-28

# %%
# 날짜 필터링
filtered_df = dexcom_df[(dexcom_df['datetime'] >= '2020-02-28 00:00:00') & (dexcom_df['datetime'] <= '2020-02-28 23:59:59')]
filtered_fl = fl_df[(fl_df['time_begin'] >= '2020-02-28 00:00:00') & (fl_df['time_begin'] <= '2020-02-28 23:59:59')]
# 인덱스를 datetime으로 설정
filtered_df.set_index('datetime', inplace=True)

# 그래프 그리기
ax = filtered_df.plot(y='Glucose Value (mg/dL)', figsize=(10, 3), legend=True)
print(filtered_df.iloc[0])

# 특정 구간 강조 (오후 2시부터 오후 6시)
for idx in range(len(filtered_fl)):
    start_time = pd.Timestamp(filtered_fl.iloc[idx]['time_begin'])
    end_time = start_time + pd.Timedelta(minutes=10)
    plt.axvspan(start_time, end_time, color='yellow', alpha=0.3)


# 그래프 제목 및 축 라벨 설정
plt.title('Glucose Value on 2020-02-28 with Highlighted Interval')
plt.xlabel('Time')
plt.ylabel('Glucose Value (mg/dL)')

# 그래프 출력
plt.show()
# Out:
# Index                                        13
# Event Type                                  EGV
# Event Subtype                               NaN
# Patient Info                                NaN
# Device Info                                 NaN
# Source Device ID                      iPhone G6
# Glucose Value (mg/dL)                     105.0
# Insulin Value (u)                           NaN
# Carb Value (grams)                          NaN
# Duration (hh:mm:ss)                         NaN
# Glucose Rate of Change (mg/dL/min)          NaN
# Transmitter Time (Long Integer)          7801.0
# Name: 2020-02-28 12:18:14, dtype: object

# %% [markdown]
# ## 2020-02-29

# %%
# 날짜 필터링
filtered_df = dexcom_df[(dexcom_df['datetime'] >= '2020-02-29 00:00:00') & (dexcom_df['datetime'] <= '2020-02-29 23:59:59')]
filtered_fl = fl_df[(fl_df['time_begin'] >= '2020-02-29 00:00:00') & (fl_df['time_begin'] <= '2020-02-29 23:59:59')]
# 인덱스를 datetime으로 설정
filtered_df.set_index('datetime', inplace=True)

# 그래프 그리기
ax = filtered_df.plot(y='Glucose Value (mg/dL)', figsize=(10, 3), legend=True)
print(filtered_df.iloc[0])

# 특정 구간 강조 (오후 2시부터 오후 6시)
for idx in range(len(filtered_fl)):
    start_time = pd.Timestamp(filtered_fl.iloc[idx]['time_begin'])
    end_time = start_time + pd.Timedelta(minutes=10)
    plt.axvspan(start_time, end_time, color='yellow', alpha=0.3)


# 그래프 제목 및 축 라벨 설정
plt.title('Glucose Value on 2020-02-29 with Highlighted Interval')
plt.xlabel('Time')
plt.ylabel('Glucose Value (mg/dL)')

# 그래프 출력
plt.show()
# Out:
# Index                                       154
# Event Type                                  EGV
# Event Subtype                               NaN
# Patient Info                                NaN
# Device Info                                 NaN
# Source Device ID                      iPhone G6
# Glucose Value (mg/dL)                     205.0
# Insulin Value (u)                           NaN
# Carb Value (grams)                          NaN
# Duration (hh:mm:ss)                         NaN
# Glucose Rate of Change (mg/dL/min)          NaN
# Transmitter Time (Long Integer)         50099.0
# Name: 2020-02-29 00:03:12, dtype: object

# %% [markdown]
# ## 2020-03-01

# %%
# 날짜 필터링
filtered_df = dexcom_df[(dexcom_df['datetime'] >= '2020-03-01 00:00:00') & (dexcom_df['datetime'] <= '2020-03-01 23:59:59')]
filtered_fl = fl_df[(fl_df['time_begin'] >= '2020-03-01 00:00:00') & (fl_df['time_begin'] <= '2020-03-01 23:59:59')]
# 인덱스를 datetime으로 설정
filtered_df.set_index('datetime', inplace=True)

# 그래프 그리기
ax = filtered_df.plot(y='Glucose Value (mg/dL)', figsize=(10, 3), legend=True)
print(filtered_df.iloc[0])

# 특정 구간 강조 (오후 2시부터 오후 6시)
for idx in range(len(filtered_fl)):
    start_time = pd.Timestamp(filtered_fl.iloc[idx]['time_begin'])
    end_time = start_time + pd.Timedelta(minutes=10)
    plt.axvspan(start_time, end_time, color='yellow', alpha=0.3)


# 그래프 제목 및 축 라벨 설정
plt.title('Glucose Value on 2020-03-01 with Highlighted Interval')
plt.xlabel('Time')
plt.ylabel('Glucose Value (mg/dL)')

# 그래프 출력
plt.show()
# Out:
# Index                                       442
# Event Type                                  EGV
# Event Subtype                               NaN
# Patient Info                                NaN
# Device Info                                 NaN
# Source Device ID                      iPhone G6
# Glucose Value (mg/dL)                     114.0
# Insulin Value (u)                           NaN
# Carb Value (grams)                          NaN
# Duration (hh:mm:ss)                         NaN
# Glucose Rate of Change (mg/dL/min)          NaN
# Transmitter Time (Long Integer)        136497.0
# Name: 2020-03-01 00:03:11, dtype: object

# %% [markdown]
# ## 2020-03-02

# %%
# 날짜 필터링
filtered_df = dexcom_df[(dexcom_df['datetime'] >= '2020-03-02 00:00:00') & (dexcom_df['datetime'] <= '2020-03-02 23:59:59')]
filtered_fl = fl_df[(fl_df['time_begin'] >= '2020-03-02 00:00:00') & (fl_df['time_begin'] <= '2020-03-02 23:59:59')]
# 인덱스를 datetime으로 설정
filtered_df.set_index('datetime', inplace=True)

# 그래프 그리기
ax = filtered_df.plot(y='Glucose Value (mg/dL)', figsize=(10, 3), legend=True)
print(filtered_df.iloc[0])

# 특정 구간 강조 (오후 2시부터 오후 6시)
for idx in range(len(filtered_fl)):
    start_time = pd.Timestamp(filtered_fl.iloc[idx]['time_begin'])
    end_time = start_time + pd.Timedelta(minutes=10)
    plt.axvspan(start_time, end_time, color='yellow', alpha=0.3)


# 그래프 제목 및 축 라벨 설정
plt.title('Glucose Value on 2020-03-02 with Highlighted Interval')
plt.xlabel('Time')
plt.ylabel('Glucose Value (mg/dL)')

# 그래프 출력
plt.show()
# Out:
# Index                                       730
# Event Type                                  EGV
# Event Subtype                               NaN
# Patient Info                                NaN
# Device Info                                 NaN
# Source Device ID                      iPhone G6
# Glucose Value (mg/dL)                     189.0
# Insulin Value (u)                           NaN
# Carb Value (grams)                          NaN
# Duration (hh:mm:ss)                         NaN
# Glucose Rate of Change (mg/dL/min)          NaN
# Transmitter Time (Long Integer)        222895.0
# Name: 2020-03-02 00:03:09, dtype: object

# %% [markdown]
# ## 2020-03-03

# %%
# 날짜 필터링
filtered_df = dexcom_df[(dexcom_df['datetime'] >= '2020-03-03 00:00:00') & (dexcom_df['datetime'] <= '2020-03-03 23:59:59')]
filtered_fl = fl_df[(fl_df['time_begin'] >= '2020-03-03 00:00:00') & (fl_df['time_begin'] <= '2020-03-03 23:59:59')]
# 인덱스를 datetime으로 설정
filtered_df.set_index('datetime', inplace=True)

# 그래프 그리기
ax = filtered_df.plot(y='Glucose Value (mg/dL)', figsize=(10, 3), legend=True)
print(filtered_df.iloc[0])

# 특정 구간 강조 (오후 2시부터 오후 6시)
for idx in range(len(filtered_fl)):
    start_time = pd.Timestamp(filtered_fl.iloc[idx]['time_begin'])
    end_time = start_time + pd.Timedelta(minutes=10)
    plt.axvspan(start_time, end_time, color='yellow', alpha=0.3)


# 그래프 제목 및 축 라벨 설정
plt.title('Glucose Value on 2020-03-03 with Highlighted Interval')
plt.xlabel('Time')
plt.ylabel('Glucose Value (mg/dL)')

# 그래프 출력
plt.show()
# Out:
# Index                                      1018
# Event Type                                  EGV
# Event Subtype                               NaN
# Patient Info                                NaN
# Device Info                                 NaN
# Source Device ID                      iPhone G6
# Glucose Value (mg/dL)                     210.0
# Insulin Value (u)                           NaN
# Carb Value (grams)                          NaN
# Duration (hh:mm:ss)                         NaN
# Glucose Rate of Change (mg/dL/min)          NaN
# Transmitter Time (Long Integer)        309293.0
# Name: 2020-03-03 00:03:07, dtype: object

# %%
# 날짜 필터링
filtered_df = dexcom_df[(dexcom_df['datetime'] >= '2020-03-04 00:00:00') & (dexcom_df['datetime'] <= '2020-03-04 23:59:59')]
filtered_fl = fl_df[(fl_df['time_begin'] >= '2020-03-04 00:00:00') & (fl_df['time_begin'] <= '2020-03-04 23:59:59')]
# 인덱스를 datetime으로 설정
filtered_df.set_index('datetime', inplace=True)

# 그래프 그리기
ax = filtered_df.plot(y='Glucose Value (mg/dL)', figsize=(10, 3), legend=True)
print(filtered_df.iloc[0])

# 특정 구간 강조 (오후 2시부터 오후 6시)
for idx in range(len(filtered_fl)):
    start_time = pd.Timestamp(filtered_fl.iloc[idx]['time_begin'])
    end_time = start_time + pd.Timedelta(minutes=10)
    plt.axvspan(start_time, end_time, color='yellow', alpha=0.3)


# 그래프 제목 및 축 라벨 설정
plt.title('Glucose Value on 2020-03-04 with Highlighted Interval')
plt.xlabel('Time')
plt.ylabel('Glucose Value (mg/dL)')

# 그래프 출력
plt.show()
# Out:
# Index                                      1306
# Event Type                                  EGV
# Event Subtype                               NaN
# Patient Info                                NaN
# Device Info                                 NaN
# Source Device ID                      iPhone G6
# Glucose Value (mg/dL)                     114.0
# Insulin Value (u)                           NaN
# Carb Value (grams)                          NaN
# Duration (hh:mm:ss)                         NaN
# Glucose Rate of Change (mg/dL/min)          NaN
# Transmitter Time (Long Integer)        395691.0
# Name: 2020-03-04 00:03:05, dtype: object
